# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from data_load import dataLoad

# %%
print('合并前')
print(dataLoad.train_images.head(3))
# Out:
# 合并前
#    patient ID ImgNumber                                            ImgPath
# 0  0000-0000L      1000  D:\Development\Workspace\AI\Tianchi-APTOS\data...
# 1  0000-0000L      1001  D:\Development\Workspace\AI\Tianchi-APTOS\data...
# 2  0000-0000L      1002  D:\Development\Workspace\AI\Tianchi-APTOS\data...

# %%
print(dataLoad.train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2366 entries, 0 to 2365
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient ID          2366 non-null   object
#  1   gender              2366 non-null   int64
#  2   age                 2366 non-null   int64
#  3   diagnosis           2366 non-null   int64
#  4   preVA               2359 non-null   float64
#  5   anti-VEGF           2366 non-null   int64
#  6   preCST              2278 non-null   float64
#  7   preIRF              2284 non-null   float64
#  8   preSRF              2284 non-null   float64
#  9   prePED              2284 non-null   float64
#  10  preHRF              2283 non-null   float64
#  11  VA                  2346 non-null   float64
#  12  continue injection  2358 non-null   float64
#  13  CST                 2213 non-null   float64
#  14  IRF                 2216 non-null   float64
#  15  SRF                 2215 non-null   float64
#  16  PED                 2215 non-null   float64
#  17  HRF                 2216 non-null   float64
# dtypes: float64(13), int64(4), object(1)
# memory usage: 332.8+ KB
# None

# %%
print(dataLoad.train_data.head(3))
# Out:
#    patient ID  gender  age  diagnosis  preVA  anti-VEGF  preCST  preIRF  \
# 0  0000-1834L       2   59          1    2.3          1     NaN     NaN
# 1  0000-1834R       2   59          6    0.3          0   310.0     0.0
# 2  0000-0673L       2   67          2    2.0          1   373.0     0.0
#
#    preSRF  prePED  preHRF   VA  continue injection    CST  IRF  SRF  PED  HRF
# 0     NaN     NaN     NaN  2.3                 0.0    NaN  NaN  NaN  NaN  NaN
# 1     0.0     1.0     0.0  0.5                 0.0    NaN  NaN  NaN  NaN  NaN
# 2     1.0     1.0     0.0  2.0                 1.0  381.0  0.0  1.0  1.0  1.0

# %%
dataLoad.merge_csv_image()

# %%
print('合并后')
# Out:
# 合并后

# %%
print(dataLoad.train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41208 entries, 0 to 41207
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient ID          41208 non-null  object
#  1   gender              41208 non-null  int64
#  2   age                 41208 non-null  int64
#  3   diagnosis           41208 non-null  int64
#  4   preVA               41110 non-null  float64
#  5   anti-VEGF           41208 non-null  int64
#  6   preCST              40675 non-null  float64
#  7   preIRF              40767 non-null  float64
#  8   preSRF              40767 non-null  float64
#  9   prePED              40767 non-null  float64
#  10  preHRF              40729 non-null  float64
#  11  VA                  40985 non-null  float64
#  12  continue injection  41112 non-null  float64
#  13  CST                 40222 non-null  float64
#  14  IRF                 40225 non-null  float64
#  15  SRF                 40201 non-null  float64
#  16  PED                 40201 non-null  float64
#  17  HRF                 40225 non-null  float64
#  18  ImgNumber           41208 non-null  object
#  19  ImgPath             41208 non-null  object
# dtypes: float64(13), int64(4), object(3)
# memory usage: 6.6+ MB
# None

# %%
print(dataLoad.train_data.head(3))
# Out:
#    patient ID  gender  age  diagnosis  preVA  anti-VEGF  preCST  preIRF  \
# 0  0000-1834L       2   59          1    2.3          1     NaN     NaN
# 1  0000-1834L       2   59          1    2.3          1     NaN     NaN
# 2  0000-1834L       2   59          1    2.3          1     NaN     NaN
#
#    preSRF  prePED  preHRF   VA  continue injection  CST  IRF  SRF  PED  HRF  \
# 0     NaN     NaN     NaN  2.3                 0.0  NaN  NaN  NaN  NaN  NaN
# 1     NaN     NaN     NaN  2.3                 0.0  NaN  NaN  NaN  NaN  NaN
# 2     NaN     NaN     NaN  2.3                 0.0  NaN  NaN  NaN  NaN  NaN
#
#   ImgNumber                                            ImgPath
# 0      1000  D:\Development\Workspace\AI\Tianchi-APTOS\data...
# 1      1001  D:\Development\Workspace\AI\Tianchi-APTOS\data...
# 2      1002  D:\Development\Workspace\AI\Tianchi-APTOS\data...

# %%
data = dataLoad.train_data.head(1)

print(data)
# Out:
#    patient ID  gender  age  diagnosis  preVA  anti-VEGF  preCST  preIRF  \
# 0  0000-1834L       2   59          1    2.3          1     NaN     NaN
#
#    preSRF  prePED  preHRF   VA  continue injection  CST  IRF  SRF  PED  HRF  \
# 0     NaN     NaN     NaN  2.3                 0.0  NaN  NaN  NaN  NaN  NaN
#
#   ImgNumber                                            ImgPath
# 0      1000  D:\Development\Workspace\AI\Tianchi-APTOS\data...

# %%
print(data['ImgPath'].values[0])
# Out:
# D:\Development\Workspace\AI\Tianchi-APTOS\data\Train_set\TrainingSet8\0000-1834\0000-1834L_1000.jpg

# %%
img = cv2.imread(data['ImgPath'].values[0])

print(img.shape)
# Out:
# (596, 1264, 3)

# %%
plt.imshow(img)
plt.show()

# %%
# 切割
img = img[:500, 500:, :]
print(img.shape)
plt.imshow(img)
plt.show()
# Out:
# (500, 764, 3)

# %%
# for img in imgs:
#     plt.imshow(img)
#     plt.show()
#     plt.imshow(img[:500, 500:, :])
#     plt.show()
#     print('*' * 80)
